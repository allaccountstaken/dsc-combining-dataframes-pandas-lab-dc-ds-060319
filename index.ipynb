# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll gain practice combining DataFrames through concatenation.  You'll also practice executing various types of joins to selectively combine the information stored in the tables!
#
# ## Objectives
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
#
#
# ## Getting Started
#
# You'll start with a quick section to gain practice with concatenating datasets using `pd.concat()`.
#
# ## Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that you have multiple DataFrames to work with, you can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
to_concat = [df1, df2, df3]
combined_df = pd.concat(to_concat)
combined_df.head(6)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="images/er1.png">
#
# ## Setting Join Conditions With Concatenation
#
# You can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, you'll execute an inner join. Before you do, you need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
to_concat = [df1, df4]
df1_and_4 = pd.concat(to_concat, join = 'inner', axis = 1)
df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='images/er2.png'>
#
# You'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that you can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways you can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!
#
# ## Loading In Data
# Now, it's time to move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  You'll make use of these keys to **_join_** the different tables together into a single DataFrame.  You'll also experiment with different types of joins to help us decide exactly what information you wish to combine.
#
# Simply run the cell below to import the tables from the database as DataFrames.

# %%
cards_df = pd.read_csv('cards.csv')
dust_df = pd.read_csv('dust.csv')
entourages_df = pd.read_csv('entourages.csv')
mechanics_df = pd.read_csv('mechanics.csv')
play_requirements_df = pd.read_csv('play_requirements.csv')

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes you created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since you are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.index, dust_df.index, entourages_df.index, mechanics_df.index, play_requirements_df.index
# Out:
# (RangeIndex(start=0, stop=2819, step=1),
#  RangeIndex(start=0, stop=4040, step=1),
#  RangeIndex(start=0, stop=328, step=1),
#  RangeIndex(start=0, stop=1079, step=1),
#  RangeIndex(start=0, stop=776, step=1))

# %%
cards_df.set_index('card_id', inplace=True)
cards_df.head()
# Out:
#            player_class    type                name      set  \
# card_id
# KARA_00_07         MAGE   SPELL       Astral Portal     KARA
# NEW1_008a         DRUID   SPELL   Ancient Teachings  EXPERT1
# BRM_010t2         DRUID  MINION  Druid of the Flame      BRM
# AT_132          NEUTRAL  MINION  Justicar Trueheart      TGT
# OG_141          NEUTRAL  MINION   Faceless Behemoth       OG
#
#                                                          text  cost  attack  \
# card_id
# KARA_00_07           Summon a random <b>Legendary</b> minion.   1.0     NaN
# NEW1_008a                                        Draw a card.   0.0     NaN
# BRM_010t2                                                 NaN   3.0     2.0
# AT_132      <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# OG_141                                                    NaN  10.0    10.0
#
#             health     rarity  collectible  \
# card_id
# KARA_00_07     NaN        NaN          NaN
# NEW1_008a      NaN        NaN          NaN
# BRM_010t2      5.0     COMMON          NaN
# AT_132         3.0  LEGENDARY          1.0
# OG_141        10.0     COMMON          1.0
#
#                                                        flavor   race  \
# card_id
# KARA_00_07                                                NaN    NaN
# NEW1_008a                                                 NaN    NaN
# BRM_010t2                                                 NaN  BEAST
# AT_132      It's like putting racing stripes and a giant s...    NaN
# OG_141      Rejected names: Forty-Foot Faceless, Big ol' N...    NaN
#
#            how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# KARA_00_07         NaN                NaN                  NaN     NaN
# NEW1_008a          NaN                NaN                  NaN     NaN
# BRM_010t2          NaN                NaN                  NaN     NaN
# AT_132             NaN                NaN                  NaN     NaN
# OG_141             NaN                NaN                  NaN     NaN
#
#             durability
# card_id
# KARA_00_07         NaN
# NEW1_008a          NaN
# BRM_010t2          NaN
# AT_132             NaN
# OG_141             NaN

# %%
dust_df.set_index('card_id', inplace=True)

# %%
entourages_df.set_index('card_id', inplace=True)

# %%
mechanics_df.set_index('card_id', inplace=True)

# %%
play_requirements_df.set_index('card_id', inplace=True)

# %% [markdown]
# ## Executing Joins
#
# Now that you have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='images/joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table you are working with, and the right table is the table you want to join to the table you are working with.  You'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table you want to join with, `mechanics_df`
# * The `how` parameter set to the type of join you want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df, how='inner', rsuffix='card_id')
cards_with_mechanics_df
# Out:
#                      player_class         type                        name  \
# card_id
# AT_002                       MAGE        SPELL                      Effigy
# AT_005t                   NEUTRAL       MINION                        Boar
# AT_006                       MAGE       MINION            Dalaran Aspirant
# AT_007                       MAGE       MINION                Spellslinger
# AT_009                       MAGE       MINION                      Rhonin
# AT_010                     HUNTER       MINION                Ram Wrangler
# AT_011e                   NEUTRAL  ENCHANTMENT            Light's Blessing
# AT_012                     PRIEST       MINION            Spawn of Shadows
# AT_017                    NEUTRAL       MINION           Twilight Guardian
# AT_018                     PRIEST       MINION         Confessor Paletress
# AT_019                    WARLOCK       MINION                  Dreadsteed
# AT_022                    WARLOCK        SPELL            Fist of Jaraxxus
# AT_023                    WARLOCK       MINION                Void Crusher
# AT_028                      ROGUE       MINION             Shado-Pan Rider
# AT_030                      ROGUE       MINION           Undercity Valiant
# AT_032                      ROGUE       MINION                Shady Dealer
# AT_035t                     ROGUE        SPELL                     Ambush!
# AT_036                      ROGUE       MINION                   Anub'arak
# AT_037                      DRUID        SPELL                Living Roots
# AT_038                      DRUID       MINION          Darnassus Aspirant
# AT_038                      DRUID       MINION          Darnassus Aspirant
# AT_039                      DRUID       MINION            Savage Combatant
# AT_039e                     DRUID  ENCHANTMENT                      Savage
# AT_040                      DRUID       MINION                  Wildwalker
# AT_042                      DRUID       MINION          Druid of the Saber
# AT_042t                     DRUID       MINION             Sabertooth Lion
# AT_042t2                    DRUID       MINION          Sabertooth Panther
# AT_045                      DRUID       MINION                      Aviana
# AT_046                     SHAMAN       MINION             Tuskarr Totemic
# AT_047                     SHAMAN       MINION         Draenei Totemcarver
# ...                           ...          ...                         ...
# TB_SPT_DPromoSecret3      WARRIOR        SPELL            Visions of Valor
# TB_SPT_DPromoSecret4      WARRIOR        SPELL             Visions of Fate
# TB_SPT_DPromoSecret5      WARRIOR        SPELL       Visions of the Amazon
# TB_SPT_DPromoSecret6      WARRIOR        SPELL     Visions of the Sorcerer
# TB_SPT_DPromoSecret7      WARRIOR        SPELL  Visions of the Necromancer
# TB_SPT_DPromoSecret9      WARRIOR        SPELL        Visions of Knowledge
# TB_SPT_DPromo_Hero2       WARRIOR         HERO                The Cow King
# TB_SPT_DpromoPortal       NEUTRAL       MINION            Enigmatic Portal
# TB_SPT_DpromoPortal       NEUTRAL       MINION            Enigmatic Portal
# TB_SPT_Minion1            NEUTRAL       MINION                  Shieldsman
# TB_SPT_Minion2            NEUTRAL       MINION             Battle Standard
# TB_SPT_Minion2            NEUTRAL       MINION             Battle Standard
# TU4c_003                  NEUTRAL       MINION                      Barrel
# TU4c_008e                 NEUTRAL  ENCHANTMENT              Might of Mukla
# TU4f_007                  NEUTRAL       MINION                Crazy Monkey
# XXX_001                   NEUTRAL        SPELL                    Damage 1
# XXX_002                   NEUTRAL        SPELL                    Damage 5
# XXX_008                   NEUTRAL        SPELL                      Freeze
# XXX_020                   NEUTRAL        SPELL            Damage all but 1
# XXX_060                   NEUTRAL        SPELL                  Damage All
# XXX_100                   NEUTRAL       MINION    Yogg-Saron Test (Manual)
# XXX_101                   NEUTRAL        SPELL          Set health to full
# XXX_102                   NEUTRAL        SPELL            Add 1 to Health.
# XXX_103                   NEUTRAL        SPELL             Add 2 to Health
# XXX_104                   NEUTRAL        SPELL            Add 4 to Health.
# XXX_105                   NEUTRAL        SPELL            Add 8 to Health.
# XXX_107                   NEUTRAL        SPELL             Set Health to 1
# XXX_110                   NEUTRAL       MINION      Yogg-Saron Test (Auto)
# hexfrog                   NEUTRAL       MINION                        Frog
# tt_010                       MAGE        SPELL                 Spellbender
#
#                            set  \
# card_id
# AT_002                     TGT
# AT_005t                    TGT
# AT_006                     TGT
# AT_007                     TGT
# AT_009                     TGT
# AT_010                     TGT
# AT_011e                    TGT
# AT_012                     TGT
# AT_017                     TGT
# AT_018                     TGT
# AT_019                     TGT
# AT_022                     TGT
# AT_023                     TGT
# AT_028                     TGT
# AT_030                     TGT
# AT_032                     TGT
# AT_035t                    TGT
# AT_036                     TGT
# AT_037                     TGT
# AT_038                     TGT
# AT_038                     TGT
# AT_039                     TGT
# AT_039e                    TGT
# AT_040                     TGT
# AT_042                     TGT
# AT_042t                    TGT
# AT_042t2                   TGT
# AT_045                     TGT
# AT_046                     TGT
# AT_047                     TGT
# ...                        ...
# TB_SPT_DPromoSecret3        TB
# TB_SPT_DPromoSecret4        TB
# TB_SPT_DPromoSecret5        TB
# TB_SPT_DPromoSecret6        TB
# TB_SPT_DPromoSecret7        TB
# TB_SPT_DPromoSecret9        TB
# TB_SPT_DPromo_Hero2         TB
# TB_SPT_DpromoPortal         TB
# TB_SPT_DpromoPortal         TB
# TB_SPT_Minion1              TB
# TB_SPT_Minion2              TB
# TB_SPT_Minion2              TB
# TU4c_003              MISSIONS
# TU4c_008e             MISSIONS
# TU4f_007              MISSIONS
# XXX_001                  CHEAT
# XXX_002                  CHEAT
# XXX_008                  CHEAT
# XXX_020                  CHEAT
# XXX_060                  CHEAT
# XXX_100                  CHEAT
# XXX_101                  CHEAT
# XXX_102                  CHEAT
# XXX_103                  CHEAT
# XXX_104                  CHEAT
# XXX_105                  CHEAT
# XXX_107                  CHEAT
# XXX_110                  CHEAT
# hexfrog                   CORE
# tt_010                 EXPERT1
#
#                                                                    text  cost  \
# card_id
# AT_002                <b>Secret:</b> When a friendly minion dies, su...   3.0
# AT_005t                                                   <b>Charge</b>   3.0
# AT_006                     <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0
# AT_007                <b>Battlecry:</b> Add a random spell to each p...   3.0
# AT_009                <b>Deathrattle:</b> Add 3 copies of Arcane Mis...   8.0
# AT_010                <b>Battlecry:</b> If you have a Beast, summon ...   5.0
# AT_011e                                               Increased Attack.   NaN
# AT_012                      <b>Inspire:</b> Deal 4 damage to each hero.   4.0
# AT_017                <b>Battlecry:</b> If you're holding a Dragon, ...   4.0
# AT_018                <b>Inspire:</b> Summon a random <b>Legendary</...   7.0
# AT_019                         <b>Deathrattle:</b> Summon a Dreadsteed.   4.0
# AT_022                When you play or discard this, deal $4 damage ...   4.0
# AT_023                <b>Inspire:</b> Destroy a random minion for ea...   6.0
# AT_028                                    <b>Combo:</b> Gain +3 Attack.   5.0
# AT_030                                     <b>Combo:</b> Deal 1 damage.   2.0
# AT_032                <b>Battlecry:</b> If you have a Pirate, gain +...   3.0
# AT_035t               When you draw this, summon a 4/4 Nerubian for ...   0.0
# AT_036                <b>Deathrattle:</b> Return this to your hand a...   9.0
# AT_037                <b>Choose One -</b> Deal $2 damage; or Summon ...   1.0
# AT_038                <b>Battlecry:</b> Gain an empty Mana Crystal.\...   2.0
# AT_038                <b>Battlecry:</b> Gain an empty Mana Crystal.\...   2.0
# AT_039                <b>Inspire:</b> Give your hero\n+2 Attack this...   4.0
# AT_039e                                            +2 Attack this turn.   NaN
# AT_040                <b>Battlecry:</b> Give a friendly Beast +3 Hea...   4.0
# AT_042                <b>Choose One -</b> Transform to gain <b>Charg...   2.0
# AT_042t                                                   <b>Charge</b>   2.0
# AT_042t2                                                 <b>Stealth</b>   2.0
# AT_045                                           Your minions cost (1).   9.0
# AT_046                   <b>Battlecry:</b> Summon a random basic Totem.   3.0
# AT_047                <b>Battlecry:</b> Gain +1/+1 for each friendly...   4.0
# ...                                                                 ...   ...
# TB_SPT_DPromoSecret3  <b>Secret:</b> When your opponent summons a Le...   2.0
# TB_SPT_DPromoSecret4  <b>Secret:</b> When your opponent takes lethal...   2.0
# TB_SPT_DPromoSecret5  <b>Secret:</b> When your opponent summons a mi...   2.0
# TB_SPT_DPromoSecret6  <b>Secret:</b> When your opponent summons a mi...   2.0
# TB_SPT_DPromoSecret7  <b>Secret:</b> When your opponent summons a mi...   2.0
# TB_SPT_DPromoSecret9  <b>Secret:</b> When your opponent's hand has 9...   2.0
# TB_SPT_DPromo_Hero2                                                 NaN   NaN
# TB_SPT_DpromoPortal   At the start of next turn, your hero is transf...   4.0
# TB_SPT_DpromoPortal   At the start of next turn, your hero is transf...   4.0
# TB_SPT_Minion1        <b>Taunt</b>\n<b>Battlecry:</b> Gain Health eq...   2.0
# TB_SPT_Minion2                         Adjacent minions have +2 Attack.   2.0
# TB_SPT_Minion2                         Adjacent minions have +2 Attack.   2.0
# TU4c_003                                   Is something in this barrel?   0.0
# TU4c_008e                           King Mukla has +8 Attack this turn.   NaN
# TU4f_007                               <b>Battlecry:</b> Throw Bananas.   1.0
# XXX_001                                                 Deal $1 damage.   0.0
# XXX_002                                                 Deal $5 damage.   0.0
# XXX_008                                      <b>Freeze</b> a character.   0.0
# XXX_020                             Set the Health of a character to 1.   0.0
# XXX_060                             Set the Health of a character to 0.   0.0
# XXX_100               <b>Battlecry:</b> Cast each spell you've cast ...   0.0
# XXX_101               Set a character's health to full, and removes ...   0.0
# XXX_102               Adds 1 health to a damaged character. Does NOT...   0.0
# XXX_103               Adds 2 health to a damaged character. Does NOT...   0.0
# XXX_104               Adds 4 health to a damaged character. Does NOT...   0.0
# XXX_105               Adds 8 health to a damaged character. Does NOT...   0.0
# XXX_107               Set a character's health to 1, and remove all ...   0.0
# XXX_110               <b>Battlecry:</b> Cast 30 random spells <i>(ta...   0.0
# hexfrog                                                    <b>Taunt</b>   0.0
# tt_010                <b>Secret:</b> When an enemy casts a spell on ...   3.0
#
#                       attack  health     rarity  collectible  \
# card_id
# AT_002                   NaN     NaN       RARE          1.0
# AT_005t                  4.0     2.0        NaN          NaN
# AT_006                   3.0     5.0     COMMON          1.0
# AT_007                   3.0     4.0     COMMON          1.0
# AT_009                   7.0     7.0  LEGENDARY          1.0
# AT_010                   3.0     3.0       RARE          1.0
# AT_011e                  NaN     NaN        NaN          NaN
# AT_012                   5.0     4.0       RARE          1.0
# AT_017                   2.0     6.0       EPIC          1.0
# AT_018                   5.0     4.0  LEGENDARY          1.0
# AT_019                   1.0     1.0       EPIC          1.0
# AT_022                   NaN     NaN       RARE          1.0
# AT_023                   5.0     4.0       RARE          1.0
# AT_028                   3.0     7.0     COMMON          1.0
# AT_030                   3.0     2.0     COMMON          1.0
# AT_032                   4.0     3.0       RARE          1.0
# AT_035t                  NaN     NaN        NaN          NaN
# AT_036                   8.0     4.0  LEGENDARY          1.0
# AT_037                   NaN     NaN     COMMON          1.0
# AT_038                   2.0     3.0       RARE          1.0
# AT_038                   2.0     3.0       RARE          1.0
# AT_039                   5.0     4.0       RARE          1.0
# AT_039e                  NaN     NaN        NaN          NaN
# AT_040                   4.0     4.0     COMMON          1.0
# AT_042                   2.0     1.0     COMMON          1.0
# AT_042t                  2.0     1.0     COMMON          NaN
# AT_042t2                 3.0     2.0     COMMON          NaN
# AT_045                   5.0     5.0  LEGENDARY          1.0
# AT_046                   3.0     2.0     COMMON          1.0
# AT_047                   4.0     4.0       RARE          1.0
# ...                      ...     ...        ...          ...
# TB_SPT_DPromoSecret3     NaN     NaN        NaN          NaN
# TB_SPT_DPromoSecret4     NaN     NaN        NaN          NaN
# TB_SPT_DPromoSecret5     NaN     NaN        NaN          NaN
# TB_SPT_DPromoSecret6     NaN     NaN        NaN          NaN
# TB_SPT_DPromoSecret7     NaN     NaN        NaN          NaN
# TB_SPT_DPromoSecret9     NaN     NaN        NaN          NaN
# TB_SPT_DPromo_Hero2      NaN    30.0        NaN          NaN
# TB_SPT_DpromoPortal      0.0    10.0        NaN          NaN
# TB_SPT_DpromoPortal      0.0    10.0        NaN          NaN
# TB_SPT_Minion1           0.0     1.0        NaN          NaN
# TB_SPT_Minion2           0.0     2.0        NaN          NaN
# TB_SPT_Minion2           0.0     2.0        NaN          NaN
# TU4c_003                 0.0     2.0     COMMON          NaN
# TU4c_008e                NaN     NaN        NaN          NaN
# TU4f_007                 1.0     2.0     COMMON          NaN
# XXX_001                  NaN     NaN     COMMON          NaN
# XXX_002                  NaN     NaN     COMMON          NaN
# XXX_008                  NaN     NaN     COMMON          NaN
# XXX_020                  NaN     NaN     COMMON          NaN
# XXX_060                  NaN     NaN        NaN          NaN
# XXX_100                  7.0     5.0  LEGENDARY          NaN
# XXX_101                  NaN     NaN     COMMON          NaN
# XXX_102                  NaN     NaN     COMMON          NaN
# XXX_103                  NaN     NaN     COMMON          NaN
# XXX_104                  NaN     NaN     COMMON          NaN
# XXX_105                  NaN     NaN     COMMON          NaN
# XXX_107                  NaN     NaN     COMMON          NaN
# XXX_110                  7.0     5.0  LEGENDARY          NaN
# hexfrog                  0.0     1.0     COMMON          NaN
# tt_010                   NaN     NaN       EPIC          1.0
#
#                                                                  flavor  \
# card_id
# AT_002                                               Burning man, brah.
# AT_005t                                                             NaN
# AT_006                 Is he aspiring or inspiring?  Make up your mind!
# AT_007                Does he sling spells, or do his spells linger ...
# AT_009                                           A masterless shamurai.
# AT_010                   Not getting trampled is really the trick here.
# AT_011e                                                             NaN
# AT_012                What did you expect to happen?  He's a Spawn. ...
# AT_017                A result of magical experiments carried out by...
# AT_018                She sees into your past and makes you face you...
# AT_019                Crescendo himself summoned this steed, riding ...
# AT_022                                   * Not actually Jaraxxus' fist.
# AT_023                                    We like to call him "Wesley".
# AT_028                He needed a break after that business in the V...
# AT_030                Almost went to play for Stormwind before signi...
# AT_032                I have great deal for you... for 4 damage to y...
# AT_035t                                                             NaN
# AT_036                Was actually a pretty nice guy before, you kno...
# AT_037                2 out of 2 saplings recommend that you summon ...
# AT_038                She loves mana crystals, she hates mana crysta...
# AT_038                She loves mana crystals, she hates mana crysta...
# AT_039                Maybe if you whistle a tune it will soothe him...
# AT_039e                                                             NaN
# AT_040                She was born to be something.  She is just not...
# AT_042                That's saberTEETH, not like curved pirate blad...
# AT_042t                                                             NaN
# AT_042t2                                                            NaN
# AT_045                Call her "Tweety".  She'll find it real funny....
# AT_046                Turns out the tuskarr aren't real choosy about...
# AT_047                It's nice to find a real craftsman in this day...
# ...                                                                 ...
# TB_SPT_DPromoSecret3                                                NaN
# TB_SPT_DPromoSecret4                                                NaN
# TB_SPT_DPromoSecret5                                                NaN
# TB_SPT_DPromoSecret6                                                NaN
# TB_SPT_DPromoSecret7                                                NaN
# TB_SPT_DPromoSecret9                                                NaN
# TB_SPT_DPromo_Hero2                                                 NaN
# TB_SPT_DpromoPortal                                                 NaN
# TB_SPT_DpromoPortal                                                 NaN
# TB_SPT_Minion1                                                      NaN
# TB_SPT_Minion2                                                      NaN
# TB_SPT_Minion2                                                      NaN
# TU4c_003                                                            NaN
# TU4c_008e                                                           NaN
# TU4f_007                                                            NaN
# XXX_001                                                             NaN
# XXX_002                                                             NaN
# XXX_008                                                             NaN
# XXX_020                                                             NaN
# XXX_060                                                             NaN
# XXX_100                                                             NaN
# XXX_101                                                             NaN
# XXX_102                                                             NaN
# XXX_103                                                             NaN
# XXX_104                                                             NaN
# XXX_105                                                             NaN
# XXX_107                                                             NaN
# XXX_110                                                             NaN
# hexfrog                                                             NaN
# tt_010                While it's fun to intercept enemy lightning bo...
#
#                         race how_to_earn how_to_earn_golden  \
# card_id
# AT_002                   NaN         NaN                NaN
# AT_005t                BEAST         NaN                NaN
# AT_006                   NaN         NaN                NaN
# AT_007                   NaN         NaN                NaN
# AT_009                   NaN         NaN                NaN
# AT_010                   NaN         NaN                NaN
# AT_011e                  NaN         NaN                NaN
# AT_012                   NaN         NaN                NaN
# AT_017                DRAGON         NaN                NaN
# AT_018                   NaN         NaN                NaN
# AT_019                 DEMON         NaN                NaN
# AT_022                   NaN         NaN                NaN
# AT_023                 DEMON         NaN                NaN
# AT_028                   NaN         NaN                NaN
# AT_030                   NaN         NaN                NaN
# AT_032                   NaN         NaN                NaN
# AT_035t                  NaN         NaN                NaN
# AT_036                   NaN         NaN                NaN
# AT_037                   NaN         NaN                NaN
# AT_038                   NaN         NaN                NaN
# AT_038                   NaN         NaN                NaN
# AT_039                 BEAST         NaN                NaN
# AT_039e                  NaN         NaN                NaN
# AT_040                   NaN         NaN                NaN
# AT_042                   NaN         NaN                NaN
# AT_042t                BEAST         NaN                NaN
# AT_042t2               BEAST         NaN                NaN
# AT_045                   NaN         NaN                NaN
# AT_046                   NaN         NaN                NaN
# AT_047                   NaN         NaN                NaN
# ...                      ...         ...                ...
# TB_SPT_DPromoSecret3     NaN         NaN                NaN
# TB_SPT_DPromoSecret4     NaN         NaN                NaN
# TB_SPT_DPromoSecret5     NaN         NaN                NaN
# TB_SPT_DPromoSecret6     NaN         NaN                NaN
# TB_SPT_DPromoSecret7     NaN         NaN                NaN
# TB_SPT_DPromoSecret9     NaN         NaN                NaN
# TB_SPT_DPromo_Hero2      NaN         NaN                NaN
# TB_SPT_DpromoPortal      NaN         NaN                NaN
# TB_SPT_DpromoPortal      NaN         NaN                NaN
# TB_SPT_Minion1           NaN         NaN                NaN
# TB_SPT_Minion2           NaN         NaN                NaN
# TB_SPT_Minion2           NaN         NaN                NaN
# TU4c_003                 NaN         NaN                NaN
# TU4c_008e                NaN         NaN                NaN
# TU4f_007                 NaN         NaN                NaN
# XXX_001                  NaN         NaN                NaN
# XXX_002                  NaN         NaN                NaN
# XXX_008                  NaN         NaN                NaN
# XXX_020                  NaN         NaN                NaN
# XXX_060                  NaN         NaN                NaN
# XXX_100                  NaN         NaN                NaN
# XXX_101                  NaN         NaN                NaN
# XXX_102                  NaN         NaN                NaN
# XXX_103                  NaN         NaN                NaN
# XXX_104                  NaN         NaN                NaN
# XXX_105                  NaN         NaN                NaN
# XXX_107                  NaN         NaN                NaN
# XXX_110                  NaN         NaN                NaN
# hexfrog                BEAST         NaN                NaN
# tt_010                   NaN         NaN                NaN
#
#                      targeting_arrow_text faction  durability  \
# card_id
# AT_002                                NaN     NaN         NaN
# AT_005t                               NaN     NaN         NaN
# AT_006                                NaN     NaN         NaN
# AT_007                                NaN     NaN         NaN
# AT_009                                NaN     NaN         NaN
# AT_010                                NaN     NaN         NaN
# AT_011e                               NaN     NaN         NaN
# AT_012                                NaN     NaN         NaN
# AT_017                                NaN     NaN         NaN
# AT_018                                NaN     NaN         NaN
# AT_019                                NaN     NaN         NaN
# AT_022                                NaN     NaN         NaN
# AT_023                                NaN     NaN         NaN
# AT_028                                NaN     NaN         NaN
# AT_030                     Deal 1 damage.     NaN         NaN
# AT_032                                NaN     NaN         NaN
# AT_035t                               NaN     NaN         NaN
# AT_036                                NaN     NaN         NaN
# AT_037                                NaN     NaN         NaN
# AT_038                                NaN     NaN         NaN
# AT_038                                NaN     NaN         NaN
# AT_039                                NaN     NaN         NaN
# AT_039e                               NaN     NaN         NaN
# AT_040                                NaN     NaN         NaN
# AT_042                                NaN     NaN         NaN
# AT_042t                               NaN     NaN         NaN
# AT_042t2                              NaN     NaN         NaN
# AT_045                                NaN     NaN         NaN
# AT_046                                NaN     NaN         NaN
# AT_047                                NaN     NaN         NaN
# ...                                   ...     ...         ...
# TB_SPT_DPromoSecret3                  NaN     NaN         NaN
# TB_SPT_DPromoSecret4                  NaN     NaN         NaN
# TB_SPT_DPromoSecret5                  NaN     NaN         NaN
# TB_SPT_DPromoSecret6                  NaN     NaN         NaN
# TB_SPT_DPromoSecret7                  NaN     NaN         NaN
# TB_SPT_DPromoSecret9                  NaN     NaN         NaN
# TB_SPT_DPromo_Hero2                   NaN     NaN         NaN
# TB_SPT_DpromoPortal                   NaN     NaN         NaN
# TB_SPT_DpromoPortal                   NaN     NaN         NaN
# TB_SPT_Minion1                        NaN     NaN         NaN
# TB_SPT_Minion2                        NaN     NaN         NaN
# TB_SPT_Minion2                        NaN     NaN         NaN
# TU4c_003                              NaN     NaN         NaN
# TU4c_008e                             NaN     NaN         NaN
# TU4f_007                              NaN     NaN         NaN
# XXX_001                               NaN     NaN         NaN
# XXX_002                               NaN     NaN         NaN
# XXX_008                               NaN     NaN         NaN
# XXX_020                               NaN     NaN         NaN
# XXX_060                               NaN     NaN         NaN
# XXX_100                               NaN     NaN         NaN
# XXX_101                               NaN     NaN         NaN
# XXX_102                               NaN     NaN         NaN
# XXX_103                               NaN     NaN         NaN
# XXX_104                               NaN     NaN         NaN
# XXX_105                               NaN     NaN         NaN
# XXX_107                               NaN     NaN         NaN
# XXX_110                               NaN     NaN         NaN
# hexfrog                               NaN     NaN         NaN
# tt_010                                NaN     NaN         NaN
#
#                                   mechanic
# card_id
# AT_002                              SECRET
# AT_005t                             CHARGE
# AT_006                             INSPIRE
# AT_007                           BATTLECRY
# AT_009                         DEATHRATTLE
# AT_010                           BATTLECRY
# AT_011e                               AURA
# AT_012                             INSPIRE
# AT_017                           BATTLECRY
# AT_018                             INSPIRE
# AT_019                         DEATHRATTLE
# AT_022                InvisibleDeathrattle
# AT_023                             INSPIRE
# AT_028                               COMBO
# AT_030                               COMBO
# AT_032                           BATTLECRY
# AT_035t                            TOPDECK
# AT_036                         DEATHRATTLE
# AT_037                          CHOOSE_ONE
# AT_038                           BATTLECRY
# AT_038                         DEATHRATTLE
# AT_039                             INSPIRE
# AT_039e                TAG_ONE_TURN_EFFECT
# AT_040                           BATTLECRY
# AT_042                          CHOOSE_ONE
# AT_042t                             CHARGE
# AT_042t2                           STEALTH
# AT_045                                AURA
# AT_046                           BATTLECRY
# AT_047                           BATTLECRY
# ...                                    ...
# TB_SPT_DPromoSecret3                SECRET
# TB_SPT_DPromoSecret4                SECRET
# TB_SPT_DPromoSecret5                SECRET
# TB_SPT_DPromoSecret6                SECRET
# TB_SPT_DPromoSecret7                SECRET
# TB_SPT_DPromoSecret9                SECRET
# TB_SPT_DPromo_Hero2   InvisibleDeathrattle
# TB_SPT_DpromoPortal              BATTLECRY
# TB_SPT_DpromoPortal                 IMMUNE
# TB_SPT_Minion1                       TAUNT
# TB_SPT_Minion2               ADJACENT_BUFF
# TB_SPT_Minion2                        AURA
# TU4c_003                       DEATHRATTLE
# TU4c_008e              TAG_ONE_TURN_EFFECT
# TU4f_007                         BATTLECRY
# XXX_001                 ImmuneToSpellpower
# XXX_002                 ImmuneToSpellpower
# XXX_008                             FREEZE
# XXX_020                 ImmuneToSpellpower
# XXX_060                 ImmuneToSpellpower
# XXX_100                          BATTLECRY
# XXX_101                 ImmuneToSpellpower
# XXX_102                 ImmuneToSpellpower
# XXX_103                 ImmuneToSpellpower
# XXX_104                 ImmuneToSpellpower
# XXX_105                 ImmuneToSpellpower
# XXX_107                 ImmuneToSpellpower
# XXX_110                          BATTLECRY
# hexfrog                              TAUNT
# tt_010                              SECRET
#
# [1079 rows x 18 columns]

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads you displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line: "Mechanis only has 1079 records"
# ________________________________________________________________________________
#
# First performed an inner join, which only includes records that are present in both tables.  Although there were 2819 records in the left table, there were only 1079 records that existed in both tables, which are what you see in the resulting dataframe.
#
# ## Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics_df.join(play_requirements_df, rsuffix = 'card_id')
left_join_df
# Out:
#                          card_id player_class         type  \
# 0                     KARA_00_07         MAGE        SPELL
# 1                      NEW1_008a        DRUID        SPELL
# 2                      BRM_010t2        DRUID       MINION
# 3                         AT_132      NEUTRAL       MINION
# 4                         OG_141      NEUTRAL       MINION
# 5                        CRED_17      NEUTRAL       MINION
# 6                        OG_337e      NEUTRAL  ENCHANTMENT
# 7                      BRMA08_1H      NEUTRAL         HERO
# 8                       GVG_011a      NEUTRAL  ENCHANTMENT
# 9                    NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                        AT_131      NEUTRAL       MINION
# 11                      CS2_122e      NEUTRAL  ENCHANTMENT
# 12                   LOEA05_02ha      NEUTRAL   HERO_POWER
# 13             CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                      CFM_334e      NEUTRAL  ENCHANTMENT
# 15                       EX1_583      NEUTRAL       MINION
# 16        TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                      LOE_007t      WARLOCK        SPELL
# 18                       CFM_095      NEUTRAL       MINION
# 19                       BRM_018      PALADIN       MINION
# 20                      PRO_001a      NEUTRAL        SPELL
# 21                     BRMA10_5H      NEUTRAL       MINION
# 22                      BRMA11_1      NEUTRAL         HERO
# 23                        OG_027       SHAMAN        SPELL
# 24                       NAX1_01      NEUTRAL         HERO
# 25                       GVG_030        DRUID       MINION
# 26                       CFM_094      WARLOCK        SPELL
# 27                   DS1h_292_H1       HUNTER   HERO_POWER
# 28                       CS2_227      NEUTRAL       MINION
# 29                       KAR_062      NEUTRAL       MINION
# ...                          ...          ...          ...
# 1049                      AT_017      NEUTRAL       MINION
# 1050                    LOEA12_1      NEUTRAL         HERO
# 1051                     GVG_035        DRUID       MINION
# 1052                     OG_104e      NEUTRAL  ENCHANTMENT
# 1053                     CS2_119      NEUTRAL       MINION
# 1054                     LOE_003         MAGE       MINION
# 1055                    LOE_113e      NEUTRAL  ENCHANTMENT
# 1056                      OG_284      NEUTRAL       MINION
# 1057                     EX1_611       HUNTER        SPELL
# 1058                      OG_340      NEUTRAL       MINION
# 1059                      OG_323      NEUTRAL       MINION
# 1060                     NAX8_03      NEUTRAL       MINION
# 1061                   LOE_089t3      NEUTRAL       MINION
# 1062                    TU4e_001       HUNTER         HERO
# 1063                     GVG_031        DRUID        SPELL
# 1064                     EX1_558      NEUTRAL       MINION
# 1065                     EX1_116      NEUTRAL       MINION
# 1066  TB_MechWar_Boss1_HeroPower      NEUTRAL   HERO_POWER
# 1067                   LOEA07_09      NEUTRAL       MINION
# 1068                      AT_114      NEUTRAL       MINION
# 1069           TB_PickYourFate_6      NEUTRAL        SPELL
# 1070                    AT_074e2      PALADIN  ENCHANTMENT
# 1071            KARA_09_07heroic      NEUTRAL        SPELL
# 1072                      AT_021      WARLOCK       MINION
# 1073                    GAME_004      NEUTRAL  ENCHANTMENT
# 1074              AT_132_SHAMANb       SHAMAN       MINION
# 1075                     BRM_014       HUNTER       MINION
# 1076                    CFM_617e      NEUTRAL  ENCHANTMENT
# 1077                   LOEA16_3e      NEUTRAL  ENCHANTMENT
# 1078                     CS2_121      NEUTRAL       MINION
#
#                          name         set  \
# 0               Astral Portal        KARA
# 1           Ancient Teachings     EXPERT1
# 2          Druid of the Flame         BRM
# 3          Justicar Trueheart         TGT
# 4           Faceless Behemoth          OG
# 5                   Rob Pardo     CREDITS
# 6          Eve of Destruction          OG
# 7          General Drakkisath         BRM
# 8                  Shrink Ray         GVG
# 9                     Harvest          TB
# 10             Eydis Darkbane         TGT
# 11                   Enhanced        CORE
# 12        Trogg Hate Minions!         LOE
# 13                   Tank Up!  HERO_SKINS
# 14                  Smuggling       GANGS
# 15         Priestess of Elune     EXPERT1
# 16         Dire Fate: Murlocs          TB
# 17                    Cursed!         LOE
# 18            Weasel Tunneler       GANGS
# 19             Dragon Consort         BRM
# 20                I Am Murloc       PROMO
# 21            Chromatic Drake         BRM
# 22    Vaelastrasz the Corrupt         BRM
# 23                     Evolve          OG
# 24                Anub'Rekhan        NAXX
# 25          Anodized Robo Cub         GVG
# 26             Felfire Potion       GANGS
# 27                Steady Shot  HERO_SKINS
# 28      Venture Co. Mercenary     EXPERT1
# 29      Netherspite Historian        KARA
# ...                       ...         ...
# 1049        Twilight Guardian         TGT
# 1050             Lady Naz'jar         LOE
# 1051                  Malorne         GVG
# 1052     Embracing the Shadow          OG
# 1053            Oasis Snapjaw        CORE
# 1054        Ethereal Conjurer         LOE
# 1055      Mrglllraawrrrglrur!         LOE
# 1056       Twilight Geomancer          OG
# 1057            Freezing Trap     EXPERT1
# 1058    Soggoth the Slitherer          OG
# 1059         Polluted Hoarder          OG
# 1060      Unrelenting Trainee        NAXX
# 1061             Grumbly Runt         LOE
# 1062        Illidan Stormrage    MISSIONS
# 1063                  Recycle         GVG
# 1064           Harrison Jones     EXPERT1
# 1065           Leeroy Jenkins     EXPERT1
# 1066     Hello! Hello! Hello!          TB
# 1067            Chasing Trogg         LOE
# 1068             Evil Heckler         TGT
# 1069            Fate: Portals          TB
# 1070        Seal of Champions         TGT
# 1071               Steal Life        KARA
# 1072      Tiny Knight of Evil         TGT
# 1073                      AFK        CORE
# 1074            Searing Totem         TGT
# 1075               Core Rager         BRM
# 1076        Visions of Hypnos       GANGS
# 1077         Lantern of Power         LOE
# 1078          Frostwolf Grunt        CORE
#
#                                                    text  cost  attack  health  \
# 0              Summon a random <b>Legendary</b> minion.   1.0     NaN     NaN
# 1                                          Draw a card.   0.0     NaN     NaN
# 2                                                   NaN   3.0     2.0     5.0
# 3     <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0     3.0
# 4                                                   NaN  10.0    10.0    10.0
# 5     You can't start a game without this minion in ...   9.0     9.0     9.0
# 6                                      Stats increased.   NaN     NaN     NaN
# 7                                                   NaN   NaN     NaN    50.0
# 8                                  -2 Attack this turn.   NaN     NaN     NaN
# 9     <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN     NaN
# 10    Whenever <b>you</b> target this minion with a ...   3.0     3.0     4.0
# 11       Raid Leader is granting this minion +1 Attack.   NaN     NaN     NaN
# 12    <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN     NaN
# 13                     <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN     NaN
# 14                         +2/+2 from Smuggler's Crate.   NaN     NaN     NaN
# 15     <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0     4.0
# 16          Turn each minion in play into a 1/1 Murloc.   0.0     NaN     NaN
# 17    While this is in your hand, take 2 damage at t...   2.0     NaN     NaN
# 18    <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0     1.0
# 19    <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0     5.0
# 20             Summon three, four, or five 1/1 Murlocs.   4.0     NaN     NaN
# 21                                                  NaN   4.0     7.0     7.0
# 22                                                  NaN   NaN     NaN    30.0
# 23    Transform your minions into random minions tha...   1.0     NaN     NaN
# 24                                                  NaN   NaN     NaN    30.0
# 25    <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0     2.0
# 26                    Deal $5 damage to all characters.   6.0     NaN     NaN
# 27    <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN     NaN
# 28                          Your minions cost (3) more.   5.0     7.0     6.0
# 29    <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0     3.0
# ...                                                 ...   ...     ...     ...
# 1049  <b>Battlecry:</b> If you're holding a Dragon, ...   4.0     2.0     6.0
# 1050                                                NaN   NaN     NaN    30.0
# 1051  <b>Deathrattle:</b> Shuffle this minion into y...   7.0     9.0     7.0
# 1052           Your healing effects are dealing damage.   NaN     NaN     NaN
# 1053                                                NaN   4.0     2.0     7.0
# 1054                <b>Battlecry: Discover</b> a spell.   5.0     6.0     3.0
# 1055                                             +2/+2.   NaN     NaN     NaN
# 1056  [x]<b>Taunt</b>\n<b>Battlecry:</b> Give your C...   2.0     1.0     4.0
# 1057  <b>Secret:</b> When an enemy minion attacks, r...   2.0     NaN     NaN
# 1058  <b>Taunt</b>\nCan't be targeted by spells or H...   9.0     5.0     9.0
# 1059                   <b>Deathrattle:</b> Draw a card.   4.0     4.0     2.0
# 1060  <b>Deathrattle:</b> Summon a Spectral Trainee ...   1.0     2.0     2.0
# 1061                                                NaN   2.0     2.0     2.0
# 1062                                                NaN   NaN     NaN    30.0
# 1063  Shuffle an enemy minion into your opponent's d...   6.0     NaN     NaN
# 1064  <b>Battlecry:</b> Destroy your opponent's weap...   5.0     5.0     4.0
# 1065  <b>Charge</b>. <b>Battlecry:</b> Summon two 1/...   5.0     6.0     2.0
# 1066  <b>Hero Power</b>\nGive your lowest attack min...   2.0     NaN     NaN
# 1067                                                NaN   4.0     2.0     6.0
# 1068                                       <b>Taunt</b>   4.0     5.0     4.0
# 1069  Shuffle 10 Unstable Portals into each player's...   0.0     NaN     NaN
# 1070                +3 Attack and <b>Divine Shield</b>.   NaN     NaN     NaN
# 1071    Deal $5 damage. Restore #5 Health to your hero.   4.0     NaN     NaN
# 1072           Whenever you discard a card, gain +1/+1.   2.0     3.0     2.0
# 1073                            Your turns are shorter.   NaN     NaN     NaN
# 1074                                                NaN   0.0     1.0     1.0
# 1075  <b>Battlecry:</b> If your hand is empty, gain ...   4.0     4.0     4.0
# 1076                                             +2/+2.   NaN     NaN     NaN
# 1077                                           +10/+10.   NaN     NaN     NaN
# 1078                                       <b>Taunt</b>   2.0     2.0     2.0
#
#          rarity  ...                                         how_to_earn  \
# 0           NaN  ...                                                 NaN
# 1           NaN  ...                                                 NaN
# 2        COMMON  ...                                                 NaN
# 3     LEGENDARY  ...                                                 NaN
# 4        COMMON  ...                                                 NaN
# 5     LEGENDARY  ...                                                 NaN
# 6           NaN  ...                                                 NaN
# 7           NaN  ...                                                 NaN
# 8           NaN  ...                                                 NaN
# 9           NaN  ...                                                 NaN
# 10    LEGENDARY  ...                                                 NaN
# 11          NaN  ...                                                 NaN
# 12          NaN  ...                                                 NaN
# 13          NaN  ...                                                 NaN
# 14          NaN  ...                                                 NaN
# 15       COMMON  ...                                                 NaN
# 16          NaN  ...                                                 NaN
# 17          NaN  ...                                                 NaN
# 18         EPIC  ...                                                 NaN
# 19         RARE  ...   Unlocked in Blackrock Spire, in the Blackrock ...
# 20          NaN  ...                                                 NaN
# 21          NaN  ...                                                 NaN
# 22          NaN  ...                                                 NaN
# 23         RARE  ...                                                 NaN
# 24          NaN  ...                                                 NaN
# 25       COMMON  ...                                                 NaN
# 26         RARE  ...                                                 NaN
# 27         FREE  ...                                                 NaN
# 28       COMMON  ...                                                 NaN
# 29       COMMON  ...    Unlocked in the Spire, in One Night in Karazhan.
# ...         ...  ...                                                 ...
# 1049       EPIC  ...                                                 NaN
# 1050        NaN  ...                                                 NaN
# 1051  LEGENDARY  ...                                                 NaN
# 1052        NaN  ...                                                 NaN
# 1053       FREE  ...                                                 NaN
# 1054     COMMON  ...   Unlocked in Uldaman, in the League of Explorer...
# 1055        NaN  ...                                                 NaN
# 1056     COMMON  ...                                                 NaN
# 1057     COMMON  ...                                                 NaN
# 1058  LEGENDARY  ...                                                 NaN
# 1059     COMMON  ...                                                 NaN
# 1060        NaN  ...                                                 NaN
# 1061        NaN  ...                                                 NaN
# 1062        NaN  ...                                                 NaN
# 1063       RARE  ...                                                 NaN
# 1064  LEGENDARY  ...                                                 NaN
# 1065  LEGENDARY  ...                                                 NaN
# 1066        NaN  ...                                                 NaN
# 1067        NaN  ...                                                 NaN
# 1068     COMMON  ...                                                 NaN
# 1069        NaN  ...                                                 NaN
# 1070        NaN  ...                                                 NaN
# 1071        NaN  ...                                                 NaN
# 1072       RARE  ...                                                 NaN
# 1073        NaN  ...                                                 NaN
# 1074        NaN  ...                                                 NaN
# 1075       RARE  ...   Unlocked in Blackrock Spire, in the Blackrock ...
# 1076        NaN  ...                                                 NaN
# 1077        NaN  ...                                                 NaN
# 1078     COMMON  ...                                                 NaN
#
#                                      how_to_earn_golden targeting_arrow_text  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# 5                                                   NaN                  NaN
# 6                                                   NaN                  NaN
# 7                                                   NaN                  NaN
# 8                                                   NaN                  NaN
# 9                                                   NaN                  NaN
# 10                                                  NaN                  NaN
# 11                                                  NaN                  NaN
# 12                                                  NaN                  NaN
# 13                                                  NaN                  NaN
# 14                                                  NaN                  NaN
# 15                                                  NaN                  NaN
# 16                                                  NaN                  NaN
# 17                                                  NaN                  NaN
# 18                                                  NaN                  NaN
# 19    Crafting unlocked in Blackrock Spire, in the B...                  NaN
# 20                                                  NaN                  NaN
# 21                                                  NaN                  NaN
# 22                                                  NaN                  NaN
# 23                                                  NaN                  NaN
# 24                                                  NaN                  NaN
# 25                                                  NaN                  NaN
# 26                                                  NaN                  NaN
# 27                                                  NaN                  NaN
# 28                                                  NaN                  NaN
# 29    Crafting unlocked in the Spire, in One Night i...                  NaN
# ...                                                 ...                  ...
# 1049                                                NaN                  NaN
# 1050                                                NaN                  NaN
# 1051                                                NaN                  NaN
# 1052                                                NaN                  NaN
# 1053                        Unlocked at Druid Level 51.                  NaN
# 1054  Crafting unlocked in Uldaman, in the League of...                  NaN
# 1055                                                NaN                  NaN
# 1056                                                NaN                  NaN
# 1057                                                NaN                  NaN
# 1058                                                NaN                  NaN
# 1059                                                NaN                  NaN
# 1060                                                NaN                  NaN
# 1061                                                NaN                  NaN
# 1062                                                NaN                  NaN
# 1063                                                NaN                  NaN
# 1064                                                NaN                  NaN
# 1065                                                NaN                  NaN
# 1066                                                NaN                  NaN
# 1067                                                NaN                  NaN
# 1068                                                NaN                  NaN
# 1069                                                NaN                  NaN
# 1070                                                NaN                  NaN
# 1071                                                NaN                  NaN
# 1072                                                NaN                  NaN
# 1073                                                NaN                  NaN
# 1074                                                NaN                  NaN
# 1075  Crafting unlocked in Blackrock Spire, in the B...                  NaN
# 1076                                                NaN                  NaN
# 1077                                                NaN                  NaN
# 1078                       Unlocked at Shaman Level 57.                  NaN
#
#        faction durability      card_idcard_id             mechanic  \
# 0          NaN        NaN              AT_132            BATTLECRY
# 1          NaN        NaN            GVG_011a  TAG_ONE_TURN_EFFECT
# 2          NaN        NaN             EX1_583            BATTLECRY
# 3          NaN        NaN            LOE_007t            EVIL_GLOW
# 4          NaN        NaN            LOE_007t   ImmuneToSpellpower
# 5          NaN        NaN             CFM_095          DEATHRATTLE
# 6          NaN        NaN             BRM_018            BATTLECRY
# 7          NaN        NaN             GVG_030           CHOOSE_ONE
# 8          NaN        NaN             GVG_030                TAUNT
# 9          NaN        NaN             CS2_227                 AURA
# 10         NaN        NaN             KAR_062            BATTLECRY
# 11         NaN        NaN         CFM_712_t17           JADE_GOLEM
# 12         NaN        NaN            BRM_011t  TAG_ONE_TURN_EFFECT
# 13         NaN        NaN           BRMA10_3H         AI_MUST_PLAY
# 14         NaN        NaN            KAR_710m                TAUNT
# 15         NaN        NaN            EX1_295o  TAG_ONE_TURN_EFFECT
# 16         NaN        NaN              OG_158          DEATHRATTLE
# 17         NaN        NaN            LOE_110t              TOPDECK
# 18         NaN        NaN            LOE_110t   ImmuneToSpellpower
# 19         NaN        NaN           BRMA13_4H         AI_MUST_PLAY
# 20         NaN        NaN            EX1_145o  TAG_ONE_TURN_EFFECT
# 21         NaN        NaN           LOEA09_2e  TAG_ONE_TURN_EFFECT
# 22         NaN        NaN            EX1_570e  TAG_ONE_TURN_EFFECT
# 23         NaN        NaN             GVG_069            BATTLECRY
# 24         NaN        NaN             hexfrog                TAUNT
# 25         NaN        NaN              OG_145        DIVINE_SHIELD
# 26         NaN        NaN              OG_145                TAUNT
# 27         NaN        NaN              AT_090              INSPIRE
# 28       HORDE        NaN              AT_060               SECRET
# 29         NaN        NaN  TB_MechWar_Minion1                TAUNT
# ...        ...        ...                 ...                  ...
# 1049       NaN        NaN             EX1_284            BATTLECRY
# 1050       NaN        NaN             LOE_038                 AURA
# 1051       NaN        NaN              AT_083              INSPIRE
# 1052       NaN        NaN    TB_CoOpv3_BOSS2e              ENRAGED
# 1053       NaN        NaN             GVG_009            BATTLECRY
# 1054       NaN        NaN             CFM_338            BATTLECRY
# 1055       NaN        NaN             GVG_097            BATTLECRY
# 1056       NaN        NaN             GVG_097                TAUNT
# 1057       NaN        NaN             CFM_852            BATTLECRY
# 1058       NaN        NaN             LOE_020            BATTLECRY
# 1059       NaN        NaN             CFM_781              STEALTH
# 1060       NaN        NaN             GVG_090            BATTLECRY
# 1061       NaN        NaN             GVG_120            BATTLECRY
# 1062       NaN        NaN            EX1_055o  TAG_ONE_TURN_EFFECT
# 1063       NaN        NaN             CFM_321            BATTLECRY
# 1064       NaN        NaN             EX1_082            BATTLECRY
# 1065  ALLIANCE        NaN             FP1_017                 AURA
# 1066       NaN        NaN             FP1_001          DEATHRATTLE
# 1067       NaN        NaN              AT_089              INSPIRE
# 1068       NaN        NaN             CFM_646          DEATHRATTLE
# 1069       NaN        NaN              AT_084            BATTLECRY
# 1070       NaN        NaN             OG_044a               CHARGE
# 1071       NaN        NaN             OG_044a                TAUNT
# 1072       NaN        NaN           LOEA09_3d         AI_MUST_PLAY
# 1073       NaN        NaN            BRMA13_4         AI_MUST_PLAY
# 1074       NaN        NaN             EX1_009              ENRAGED
# 1075       NaN        NaN            BRMA10_3         AI_MUST_PLAY
# 1076       NaN        NaN            NAX3_02H         AI_MUST_PLAY
# 1077       NaN        NaN             AT_083e  TAG_ONE_TURN_EFFECT
# 1078       NaN        NaN             CS2_031               FREEZE
#
#          card_idcard_id           play_requirement value
# 0            KARA_00_07       REQ_NUM_MINION_SLOTS   1.0
# 1              PRO_001a       REQ_NUM_MINION_SLOTS   1.0
# 2               NAX1_01       REQ_NUM_MINION_SLOTS   1.0
# 3           DS1h_292_H1            REQ_STEADY_SHOT   0.0
# 4           DS1h_292_H1   REQ_MINION_OR_ENEMY_HERO   0.0
# 5               KAR_076         REQ_TARGET_TO_PLAY   0.0
# 6                AT_024         REQ_TARGET_TO_PLAY   0.0
# 7                AT_024       REQ_TARGET_WITH_RACE  15.0
# 8                AT_024          REQ_MINION_TARGET   0.0
# 9              BRMA06_2       REQ_NUM_MINION_SLOTS   1.0
# 10              NAX5_02  REQ_MINIMUM_ENEMY_MINIONS   1.0
# 11              OG_080c        REQ_FRIENDLY_TARGET   0.0
# 12              OG_080c         REQ_TARGET_TO_PLAY   0.0
# 13              OG_080c          REQ_MINION_TARGET   0.0
# 14              CS2_039         REQ_TARGET_TO_PLAY   0.0
# 15              CS2_039          REQ_MINION_TARGET   0.0
# 16    TB_KaraPortal_002          REQ_MINION_TARGET   0.0
# 17              CS2_094         REQ_TARGET_TO_PLAY   0.0
# 18      TB_SPT_DPromoHP          REQ_MINION_TARGET   0.0
# 19             BRMA15_3       REQ_NUM_MINION_SLOTS   1.0
# 20              CS2_141    REQ_TARGET_IF_AVAILABLE   0.0
# 21              CS2_141         REQ_NONSELF_TARGET   0.0
# 22              CS2_063         REQ_TARGET_TO_PLAY   0.0
# 23              CS2_063          REQ_MINION_TARGET   0.0
# 24              CS2_063           REQ_ENEMY_TARGET   0.0
# 25             GVG_055e        REQ_FRIENDLY_TARGET   0.0
# 26               TB_006         REQ_TARGET_TO_PLAY   0.0
# 27               TB_006          REQ_MINION_TARGET   0.0
# 28           CFM_621t21  REQ_MINIMUM_TOTAL_MINIONS   1.0
# 29           LOEA06_04h         REQ_TARGET_TO_PLAY   0.0
# ...                 ...                        ...   ...
# 1049                NaN                        NaN   NaN
# 1050                NaN                        NaN   NaN
# 1051                NaN                        NaN   NaN
# 1052                NaN                        NaN   NaN
# 1053                NaN                        NaN   NaN
# 1054                NaN                        NaN   NaN
# 1055                NaN                        NaN   NaN
# 1056                NaN                        NaN   NaN
# 1057                NaN                        NaN   NaN
# 1058                NaN                        NaN   NaN
# 1059                NaN                        NaN   NaN
# 1060                NaN                        NaN   NaN
# 1061                NaN                        NaN   NaN
# 1062                NaN                        NaN   NaN
# 1063                NaN                        NaN   NaN
# 1064                NaN                        NaN   NaN
# 1065                NaN                        NaN   NaN
# 1066                NaN                        NaN   NaN
# 1067                NaN                        NaN   NaN
# 1068                NaN                        NaN   NaN
# 1069                NaN                        NaN   NaN
# 1070                NaN                        NaN   NaN
# 1071                NaN                        NaN   NaN
# 1072                NaN                        NaN   NaN
# 1073                NaN                        NaN   NaN
# 1074                NaN                        NaN   NaN
# 1075                NaN                        NaN   NaN
# 1076                NaN                        NaN   NaN
# 1077                NaN                        NaN   NaN
# 1078                NaN                        NaN   NaN
#
# [1079 rows x 23 columns]

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if you were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# Every record from `cards_with_mechanics_df`, as well as any records from `play_requirements_df` that have matching index values with a record from the left table.
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = None
outer_join_df

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, you learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
